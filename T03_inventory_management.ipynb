# %%
products = []


def add_product():
    """Add a new product to inventory."""
    name = input("Enter product name: ")

    try:
        price = float(input("Enter price: ₹"))
        quantity = int(input("Enter quantity: "))

        product = {
            "name": name,
            "price": price,
            "quantity": quantity
        }

        products.append(product)

        print("Product added successfully.")

    except ValueError:
        print("Invalid price or quantity.")


def display_products():
    """Display all products."""
    if len(products) == 0:
        print("Inventory is empty.")
        return

    print("\n--- INVENTORY ---")

    for product in products:
        print("Name:", product["name"],
            "| Price: ₹", product["price"],
            "| Quantity:", product["quantity"]
        )


def search_product():
    """Search product by name."""
    search_name = input("Enter product name to search: ")

    for product in products:

        if product["name"].lower() == search_name.lower():
            print("Product found:", product)
            return

    print("Product not found.")


def update_quantity():
    """Update quantity of an existing product."""
    name = input("Enter product name: ")

    for product in products:

        if product["name"].lower() == name.lower():

            try:
                quantity = int(input("Enter new quantity: "))
                product["quantity"] = quantity

                print("Quantity updated.")
                return

            except ValueError:
                print("Enter a valid quantity.")
                return

    print("Product not found.")


def calculate_inventory_value():
    """Calculate total inventory value."""
    total = 0

    for product in products:
        total += product["price"] * product["quantity"]

    print("Total inventory value: ₹", total)


while True:

    print("\n--- INVENTORY MANAGEMENT ---")
    print("1. Add Product")
    print("2. Display Products")
    print("3. Search Product")
    print("4. Update Quantity")
    print("5. Inventory Value")
    print("6. Exit")

    choice = input("Enter choice: ")

    if choice == "1":
        add_product()

    elif choice == "2":
        display_products()

    elif choice == "3":
        search_product()

    elif choice == "4":
        update_quantity()

    elif choice == "5":
        calculate_inventory_value()

    elif choice == "6":
        break

    else:
        print("Invalid choice.")
# Out:
# --- INVENTORY MANAGEMENT ---
# 1. Add Product
# 2. Display Products
# 3. Search Product
# 4. Update Quantity
# 5. Inventory Value
# 6. Exit
# Product added successfully.
#
# --- INVENTORY MANAGEMENT ---
# 1. Add Product
# 2. Display Products
# 3. Search Product
# 4. Update Quantity
# 5. Inventory Value
# 6. Exit
# Product added successfully.
#
# --- INVENTORY MANAGEMENT ---
# 1. Add Product
# 2. Display Products
# 3. Search Product
# 4. Update Quantity
# 5. Inventory Value
# 6. Exit
# Quantity updated.
#
# --- INVENTORY MANAGEMENT ---
# 1. Add Product
# 2. Display Products
# 3. Search Product
# 4. Update Quantity
# 5. Inventory Value
# 6. Exit
# Product found: {'name': 'Camera', 'price': 15000.0, 'quantity': 4}
#
# --- INVENTORY MANAGEMENT ---
# 1. Add Product
# 2. Display Products
# 3. Search Product
# 4. Update Quantity
# 5. Inventory Value
# 6. Exit
# Product not found.
#
# --- INVENTORY MANAGEMENT ---
# 1. Add Product
# 2. Display Products
# 3. Search Product
# 4. Update Quantity
# 5. Inventory Value
# 6. Exit
# Total inventory value: ₹ 260000.0
#
# --- INVENTORY MANAGEMENT ---
# 1. Add Product
# 2. Display Products
# 3. Search Product
# 4. Update Quantity
# 5. Inventory Value
# 6. Exit
#
# --- INVENTORY ---
# Name: Camera | Price: ₹ 15000.0 | Quantity: 4
# Name: phone | Price: ₹ 20000.0 | Quantity: 10
#
# --- INVENTORY MANAGEMENT ---
# 1. Add Product
# 2. Display Products
# 3. Search Product
# 4. Update Quantity
# 5. Inventory Value
# 6. Exit
